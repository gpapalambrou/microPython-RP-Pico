# %% [markdown]
# ## Kιτ RP Pico
#
# <div class="alert alert-block alert-warning">
# <b>Για το 2025 δίνεται κιτ που περιλαμβάνει τα εξής εξαρτήματα (ακολουθεί φωτό):</b>
#
#
# 1. RP Pico 2040 (με αρχείο uf2), https://www.nettop.gr/index.php/raspberry-pi/pico/raspberry-pi-pico-kits/raspberry-pi-pico-2.html
# 1. Breadboard, 400 point, https://www.nettop.gr/index.php/make/prototyping/breadboards-protoboards/400-point-breadboard.html
# 1. Jumper wires, male to male, https://www.nettop.gr/index.php/make/prototyping/jumper-wiring/40p-10cm-dupont-wire-male-to-male.html
# 1. Led 3 mm, https://www.nettop.gr/index.php/hlektronika/leds/3mm-leds/3mm-led-diffused-red.html
# 1. Potentiometer 100K, https://www.nettop.gr/index.php/hlektronika/potentiometer/potentiometer-1/100k-104-horizontal-trimpot-potentiometer.html
# 1. Button, https://www.nettop.gr/index.php/eksartimata/diakoptes/10-kinds-values-180pcs-tactile-push-button-switch-assortment.html
# 1. Resistor ~ 460 Ohm, πχ https://www.nettop.gr/index.php/hlektronika/resistors/resistors1-4w/10x-1-4w-antistasi-330ohm.html
#
# Επίσης χρειάζεστε
# 1.  Καλώδιο Micro-USB to USB Type-A, https://www.nettop.gr/index.php/raspberry-pi/raspberry-pi-zero/raspberry-pi-zero-aksesouar/usb-a-male-to-micro-usb-5p-male-1m-red.html
#
#
# Μπορείτε να προμηθευτείτε τα ηλεκτρονικά εξαρτήματα από http://nettop.gr/, Διεύθυνση: Κρέμου 107 Καλλιθέα Αττικής, e-mail: info@nettop.gr, Τηλ: 210 9511222, Ελλάδα.
#
# </div>

# %% [markdown]
# ![kitRP.jpg](attachment:4810d14b-4a32-40bf-bdc2-db1126e6d254.jpg)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Τα υπόλοιπα κυκλώματα για το RP Pico</b>
#
#
# Πλακέτες:
# - MPU6050-Accelerometer,
# - SS49-Magnetic sensor,
# - INA219-Current sensor,
# - K-thermocouple & MAX31856,
# - DHT22-Humidity/Temperature sensor
# </div>

# %% [markdown]
# ![kitRP_modules.jpg](attachment:108e6b68-03ff-4f50-9936-d63f308aa5c2.jpg)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Just don't:</b> In general, avoid the red boxes.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Up to you:</b> Use green boxes sparingly
# </div>
