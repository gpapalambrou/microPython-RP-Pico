# %% [markdown]
# ## Kιτ RP Pico
#
# <div class="alert alert-block alert-warning">
# <b>Για το 2025 δίνεται κιτ που περιλαμβάνει τα εξής εξαρτήματα (ακολουθεί φωτό):</b>
#
#
# 1. RP Pico 2040 (με αρχείο uf2), https://www.nettop.gr/index.php/raspberry-pi/pico/raspberry-pi-pico-kits/raspberry-pi-pico-2.html
# 1. Breadboard, 400 point, https://www.nettop.gr/index.php/make/prototyping/breadboards-protoboards/400-point-breadboard.html
# 1. Jumper wires, male to male, https://www.nettop.gr/index.php/make/prototyping/jumper-wiring/40p-10cm-dupont-wire-male-to-male.html
# 1. Led 3 mm, https://www.nettop.gr/index.php/hlektronika/leds/3mm-leds/3mm-led-diffused-red.html
# 1. Potentiometer 100K, https://www.nettop.gr/index.php/hlektronika/potentiometer/potentiometer-1/100k-104-horizontal-trimpot-potentiometer.html
# 1. Button, https://www.nettop.gr/index.php/eksartimata/diakoptes/10-kinds-values-180pcs-tactile-push-button-switch-assortment.html
# 1. Resistor ~ 460 Ohm, πχ https://www.nettop.gr/index.php/hlektronika/resistors/resistors1-4w/10x-1-4w-antistasi-330ohm.html
#
# Επίσης χρειάζεστε
# 1.  Καλώδιο Micro-USB to USB Type-A, https://www.nettop.gr/index.php/raspberry-pi/raspberry-pi-zero/raspberry-pi-zero-aksesouar/usb-a-male-to-micro-usb-5p-male-1m-red.html
#
#
# Μπορείτε να προμηθευτείτε τα ηλεκτρονικά εξαρτήματα από:
# - Nettop, http://nettop.gr/, Κρέμου 107 Καλλιθέα Αττικής.
# - Grobotronics, https://grobotronics.com/, Αθήνα.
# </div>

# %% [markdown]
# ![rp_kit.png](attachment:30f51ec4-6b28-4120-84ea-1c3cda2cac28.png)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Hλεκτρονικά που μπορούν να συνδεθούν σε ένα RP Pico:
# </b>
#
# ### GY-521 MPU-6050 Triple Axis  Accelerometer & Gyroscope  (I2C bus)
#
# - https://www.nettop.gr/index.php/eksartimata/aisthitires/accelerometers/gy-521-mpu-6050-mpu6050-sensor.html.
# - Datasheet: https://www.haoyuelectronics.com/Attachment/GY-521/mpu6050.pdf
#
#
# ### INA219-Current sensor  (I2C bus)
#
# - https://grobotronics.com/ina219-high-side-dc-current-sensor-breakout-26v-3.2a-max.html,
# - Datasheet: https://cdn-shop.adafruit.com/datasheets/ina219.pdf
#
#
# ### K-thermocouple & Universal Thermocouple Amplifier MAX31856 (SPI bus)
#
# - K-thermocouple: https://grobotronics.com/pimoroni-braided-k-type-thermocouple.html,
# - MAX31856: https://www.adafruit.com/product/3263,
# - MCP9600: https://grobotronics.com/pimoroni-mcp9600-thermocouple-amplifier-breakout.html
#
#
# ### SS49-Magnetic sensor (Analog input)
#
# - https://grobotronics.com/hall-effect-sensor-linear-ss49-bipolar.html,
# - Datasheet: https://grobotronics.com/images/companies/1/ss49-ss19.pdf
#
#
# ### DHT22-Humidity/Temperature sensor (digital signal via single-bus)
#
# - https://www.nettop.gr/index.php/eksartimata/aisthitires/humidity-temperature/dht22.html, https://grobotronics.com/rht03-dht22.html,
# - Datasheet: https://grobotronics.com/images/companies/1/DHT22-datasheetAm2302.pdf?1612948682574
#
#
# </div>

# %% [markdown]
# ![rp_modules.png](attachment:d3922740-30c0-49a9-a103-435555b655fe.png)

# %% [markdown]
# Η εικόνα Α-1 δείχνει τα βασικά εξαρτήματα ηλεκτρονικής.

# %% [markdown]
# ![electronics.png](electronics.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not
# inside code cells, or use for mathematical formulas if needed.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Just don't:</b> In general, avoid the red boxes.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Up to you:</b> Use green boxes sparingly
# </div>
